# %% [markdown]
# <a href="https://colab.research.google.com/github/Dominic-Virtucio/DSA-CpE-010-CpE12S4/blob/main/Hands_on_Activity_1_1_Using_Pseudo_code_Statements_and_Flowchart_Symbols.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Hands-on Activity 1.1: Using Pseudo-code Statements and Flowchart Symbols
#
# Additional Activities:
# 1. Design an algorithm and the corresponding flowchart for finding the sum of the numbers 2, 4, 6, 8, …, n (output: Algorithm and Flowchart)
# START
#     Initialize variables
#         Set sum = 0
#         Set i = 2
#     Read n
#     while i <= n
#         sum = sum + i
#         i = i + 2
#     End While
#     Display sum
# STOP
#
# 2. Write an algorithm to read 100 numbers and then display the sum.
# START
#     Initialize Variables
#         Set i = 1
#         Set sum = 0
#         Set count = 0
#     Loop to read 100 numbers
#         IF count < 100
#             Read num
#             sum = sum + num
#             Set count = count + 1
#         End IF
#     End Loop
#     Print sum
# STOP
#
#
# 3. Write an algorithm to read two numbers then display the largest.
# START
#     Initialize Variables
#         Read num1
#         Read num2
#
#     Compare variables using if-else
#         IF num1 > num2 THEN
#             Set Largest = num1
#         ELSE
#             Set Largest = num2
#         END IF
#
#     PRINT Largest
#
# STOP
#
# 4. Write an algorithm to read two numbers then display the smallest
# START
#     Initialize Variables
#         Read num1
#         Read num2
#
#     Compare variables using if-else:
#         IF num1 < num2 THEN
#             Set Smallest = num1
#         ELSE
#             Set Smallest = num2
#         END IF
#
#     PRINT Smallest
#
# STOP
#
# 5. Write an algorithm to read three numbers then display the largest.
# START
#     Initialize Variables
#         Read num1
#         Read num2
#         Read num3
#
#     Compare variables
#         IF num1 >= num2 AND num1 >= num3 THEN
#             Set Largest = num1
#         ELSE IF num2 >= num1 AND num2 >= num3 THEN
#             Set Largest = num2
#         ELSE
#             Set Largest = num3
#         END IF
#
#     Print Largest
#
# STOP
#
# 6. Write an algorithm to read 100 numbers then display the largest.
# START
#     Initialize variables
#         Set largest = - ∞
#         Set count = 0
#
#     Loop to read 100 numbers
#         WHILE count < 100
#             Read a number
#             Read num
#
#             Update largest if needed
#             IF num > largest THEN
#                 Set largest = num
#             END IF
#
#             Increment the count
#             Set count = count + 1
#         END WHILE
#
#     Display the largest number
#     Print largest
#
# STOP

# %%
##Hands-on Activity 1.1: Using Pseudo-code Statements and Flowchart Symbols

# %% [markdown]
# Additional Activities:
# 1. Design an algorithm and the corresponding flowchart for finding the sum of the numbers 2, 4, 6, 8, …, n (output: Algorithm and Flowchart)
# START
#     Initialize variables
#         Set sum = 0
#         Set i = 2
#     Read n
#     while i <= n
#         sum = sum + i
#         i = i + 2
#     End While
#     Display sum
# STOP
#
# 2. Write an algorithm to read 100 numbers and then display the sum.
# START
#     Initialize Variables
#         Set i = 1
#         Set sum = 0
#         Set count = 0
#     Loop to read 100 numbers
#         IF count < 100
#             Read num
#             sum = sum + num
#             Set count = count + 1
#         End IF
#     End Loop
#     Print sum
# STOP
#
#
# 3. Write an algorithm to read two numbers then display the largest.
# START
#     Initialize Variables
#         Read num1
#         Read num2
#
#     Compare variables using if-else
#         IF num1 > num2 THEN
#             Set Largest = num1
#         ELSE
#             Set Largest = num2
#         END IF
#
#     PRINT Largest
#
# STOP
#
# 4. Write an algorithm to read two numbers then display the smallest
# START
#     Initialize Variables
#         Read num1
#         Read num2
#
#     Compare variables using if-else:
#         IF num1 < num2 THEN
#             Set Smallest = num1
#         ELSE
#             Set Smallest = num2
#         END IF
#
#     PRINT Smallest
#
# STOP
#
# 5. Write an algorithm to read three numbers then display the largest.
# START
#     Initialize Variables
#         Read num1
#         Read num2
#         Read num3
#
#     Compare variables
#         IF num1 >= num2 AND num1 >= num3 THEN
#             Set Largest = num1
#         ELSE IF num2 >= num1 AND num2 >= num3 THEN
#             Set Largest = num2
#         ELSE
#             Set Largest = num3
#         END IF
#
#     Print Largest
#
# STOP
#
# 6. Write an algorithm to read 100 numbers then display the largest.
# START
#     Initialize variables
#         Set largest = - ∞
#         Set count = 0
#
#     Loop to read 100 numbers
#         WHILE count < 100
#             Read a number
#             Read num
#
#             Update largest if needed
#             IF num > largest THEN
#                 Set largest = num
#             END IF
#
#             Increment the count
#             Set count = count + 1
#         END WHILE
#
#     Display the largest number
#     Print largest
#
# STOP

# %% [markdown]
# ![Problem1_Virtucio (1).png](data:image/png;base64,...)

# %% [markdown]
# ![Additional1_Virtucio.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ![Additional1_Virtucio.drawio.png](data:image/png;base64,...)
